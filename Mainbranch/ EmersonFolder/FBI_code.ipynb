# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt

from pprint import pprint
import scipy.stats as stats

# %%
api_key = 'gD3972hTja7jXzMfpTWNIzJjVPhJZJrc5PV8c7w9'

# %%
state = ["CA", "MN"]


url = f'https://api.usa.gov/crime/fbi/cde/agency/byStateAbbr/MN?API_KEY=gD3972hTja7jXzMfpTWNIzJjVPhJZJrc5PV8c7w9'

response = requests.get(url).json()

#response

# %%
state = ["CA", "MN", "WA", 'OH', 'TX', 'IN', 'MT']
agency = []
state_name = []
counties = ['SAN FRANCISCO', 'SAN MATEO', 'ST LOUIS', 'KING', 'DALLAS', 'MARION', 'MISSOULA', 'CUYAHOGA', "TARRANT"]
types = ['City', 'County']

for state in state:
    url = f'https://api.usa.gov/crime/fbi/cde/agency/byStateAbbr/{state}?API_KEY=gD3972hTja7jXzMfpTWNIzJjVPhJZJrc5PV8c7w9'
    response = requests.get(url).json()
    for i in range(len(response)):
        test = response[i]["county_name"]
        test2 = response[1]['agency_type_name']
        if test in counties and test2 in types:
            blank = response[i]['ori']
            agency.append(blank)
            state_name.append(response[i]['state_name'])
        else:
            print(f"{test} is not a county")
# Out:
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALAMEDA is not a county
# ALPINE is not a county
# AMADOR is not a county
# AMADOR is not a county
# AMADOR is not a county
# AMADOR is not a county
# AMADOR is not a county
# AMADOR is not a county
# BUTTE is not a county
# BUTTE is not a county
# BUTTE is not a county
# BUTTE is not a county
# ...

# %%
state_name

test5 = {
    "State Name":state_name,
    "Agency": agency
}

test_df = pd.DataFrame(test5)
test_df

empty_cities = []

for index, row in test_df.iterrows():
    if row['State Name']=="California":
        empty_cities.append("San Francisco, CA")
    if row['State Name']=="Minnesota":
        empty_cities.append("Virginia, MN")
    if row['State Name']=="Washington":
        empty_cities.append("Seattle, WA")
    if row['State Name']=="Ohio":
        empty_cities.append("Cleveland, OH")
    if row['State Name']=="Texas":
        empty_cities.append("Dallas, TX")
    if row['State Name']=="Indiana":
        empty_cities.append("Indianapolis, IN")
    if row['State Name']=="Montana":
        empty_cities.append("Missoula, MT")

test_df['City Name'] = empty_cities

test_df = test_df[['City Name', 'Agency']]
test_df
# Out:
#              City Name     Agency
# 0    San Francisco, CA  CA0380000
# 1    San Francisco, CA  CA0380100
# 2    San Francisco, CA  CA0380300
# 3    San Francisco, CA  CA0380500
# 4    San Francisco, CA  CA0381900
# ..                 ...        ...
# 221   Indianapolis, IN  IN0495300
# 222   Indianapolis, IN  INIPD0000
# 223       Missoula, MT  MT0320000
# 224       Missoula, MT  MT0320100
# 225       Missoula, MT  MT0320300
#
# [226 rows x 2 columns]

# %%
base_url = 'https://api.usa.gov/crime/fbi/cde'
url = f"{base_url}/arrest/agency/CA0380300/violent_crime?from=2017&to=2017&API_KEY={api_key}"
response = requests.get(url).json()
response['data'][0]['data_year']
# Out:
# 2017

# %%
base_url = 'https://api.usa.gov/crime/fbi/cde'

agency

crime_simple_assault = []
crime_aggravated_assault = []
crime_robbery = []
crime_murder= []
crime_manslaughter = []
agency2 = []
year = []

for i in agency:
    url = f"{base_url}/arrest/agency/{i}/violent_crime?from=2020&to=2020&API_KEY={api_key}"
    response = requests.get(url).json()
    try:
        year.append(response['data'][0]['data_year'])
        crime_simple_assault.append(response['data'][0]['Simple Assault'])
        crime_aggravated_assault.append(response['data'][0]['Aggravated Assault'])
        crime_robbery.append(response['data'][0]['Robbery'])
        crime_murder.append(response['data'][0]['Murder and Nonnegligent Manslaughter'])
        crime_manslaughter.append(response['data'][0]['Manslaughter by Negligence'])
        agency2.append(i)
        print(f'{i}')
    except(IndexError):
        print(f"{i} has no data")

crime_df = {
    "Simple Assault" :crime_simple_assault,
    "Aggravated Assault": crime_aggravated_assault,
    "Robbery": crime_robbery,
    "Murder": crime_murder,
    "Manslaughter": crime_manslaughter,
    "Agency":agency2,
    "Year": year
    
}

df = pd.DataFrame(crime_df)
df

final_df = pd.merge(df, test_df, how="left", on="Agency")


#final_df.drop((final_df['Simple Assault']==0) & (final_df['Aggravated Assault']==0))


crime_df2021 = final_df[~((final_df['Simple Assault'] == 0) & (final_df['Aggravated Assault'] == 0) & (final_df['Robbery'] == 0) & (final_df['Murder'] == 0) & (final_df['Manslaughter'] == 0))]
crime_df2021
# Out:
# CA0380000 has no data
# CA0380100
# CA0380300
# CA0380500
# CA0381900 has no data
# CA0389700
# CA0389921 has no data
# CA0389935 has no data
# CA0410000
# CA0410100
# CA0410200
# CA0410300
# CA0410400
# CA0410500
# CA0410600
# CA0410800
# CA0410900
# CA0411100
# CA0411300
# CA0411400
# CA0411600
# CA0411700
# CA0411900
# CA0412000
# CA0412300
# CA041240X has no data
# CA0412700
# CA0419930 has no data
# MN0690000
# MN0690200
# MN0690500
# MN0690600
# MN0690700
# MN0690800
# MN0690900
# MN0691000
# MN0691300
# MN0691400
# MN0691500
# MN0691700
# MN0691800
# MN0692100
# MN0694400
# MNMHP1000
# MNMHP1100
# WA0170000
# WA0170200
# WA0170400
# WA0170600
# WA0170700
# WA0170800
# WA0170900
# WA0171000
# WA0171100
# WA0171200
# WA0171300
# WA0171400
# WA0171500
# WA0171600
# WA0171700
# WA0171800
# WA0172000
# WA0172200
# WA0172300
# WA0172400
# WA0172500
# WA0172600
# WA0172700 has no data
# WA0172900 has no data
# WA0173100
# WA0173200
# WA0173600
# WA0173700
# WA0174000
# WA0174100
# ...

# %%
base_url = 'https://api.usa.gov/crime/fbi/cde'

agency

crime_simple_assault = []
crime_aggravated_assault = []
crime_robbery = []
crime_murder= []
crime_manslaughter = []
agency2 = []
year = []

for i in agency:
    url = f"{base_url}/arrest/agency/{i}/violent_crime?from=2017&to=2017&API_KEY={api_key}"
    response = requests.get(url).json()
    try:
        year.append(response['data'][0]['data_year'])
        crime_simple_assault.append(response['data'][0]['Simple Assault'])
        crime_aggravated_assault.append(response['data'][0]['Aggravated Assault'])
        crime_robbery.append(response['data'][0]['Robbery'])
        crime_murder.append(response['data'][0]['Murder and Nonnegligent Manslaughter'])
        crime_manslaughter.append(response['data'][0]['Manslaughter by Negligence'])
        agency2.append(i)
        print(f'{i}')
    except(IndexError):
        print(f"{i} has no data")



crime_df = {
    "Simple Assault" :crime_simple_assault,
    "Aggravated Assault": crime_aggravated_assault,
    "Robbery": crime_robbery,
    "Murder": crime_murder,
    "Manslaughter": crime_manslaughter,
    "Agency":agency2,
    "Year": year
}

df = pd.DataFrame(crime_df)
df

final_df = pd.merge(df, test_df, how="left", on="Agency")


crime_df2017 = final_df[~((final_df['Simple Assault'] == 0) & (final_df['Aggravated Assault'] == 0) & (final_df['Robbery'] == 0) & (final_df['Murder'] == 0) & (final_df['Manslaughter'] == 0))]
crime_df2017
# Out:
# CA0380000 has no data
# CA0380100
# CA0380300
# CA0380500
# CA0381900 has no data
# CA0389700
# CA0389921 has no data
# CA0389935 has no data
# CA0410000
# CA0410100
# CA0410200
# CA0410300
# CA0410400
# CA0410500
# CA0410600
# CA0410800
# CA0410900
# CA0411100
# CA0411300
# CA0411400
# CA0411600
# CA0411700
# CA0411900
# CA0412000
# CA0412300
# CA041240X has no data
# CA0412700
# CA0419930 has no data
# MN0690000
# MN0690200
# MN0690500
# MN0690600
# MN0690700
# MN0690800
# MN0690900
# MN0691000
# MN0691300
# MN0691400
# MN0691500
# MN0691700
# MN0691800
# MN0692100
# MN0694400
# MNMHP1000
# MNMHP1100
# WA0170000 has no data
# WA0170200
# WA0170400
# WA0170600
# WA0170700
# WA0170800
# WA0170900
# WA0171000
# WA0171100
# WA0171200
# WA0171300
# WA0171400
# WA0171500
# WA0171600 has no data
# WA0171700
# WA0171800 has no data
# WA0172000
# WA0172200
# WA0172300
# WA0172400
# WA0172500
# WA0172600
# WA0172700 has no data
# WA0172900 has no data
# WA0173100
# WA0173200
# WA0173600
# ...

# %%
final_crime = pd.merge(crime_df2017, crime_df2021, how="inner", on =["Agency", "City Name"])
final_crime
# Out:
#      Simple Assault_x  Aggravated Assault_x  Robbery_x  Murder_x  \
# 0                1230                  1570        360        38
# 1                   3                     0          1         0
# 2                  70                    12          8         0
# 3                  36                     8          0         0
# 4                 138                   125         25         1
# ..                ...                   ...        ...       ...
# 138                47                    14         13         0
# 139              3304                  2194        749        70
# 140                65                    32          0         0
# 141               492                    60          8         2
# 142                 8                     1          0         0
#
#      Manslaughter_x     Agency  Year_x          City Name  Simple Assault_y  \
# 0                 1  CA0380100    2017  San Francisco, CA              1111
# ...

# %%
crime_df2021_group = crime_df2021.groupby(['City Name', 'Year']).sum().sort_values(ascending=False, by='Simple Assault')
crime_df2021_group
# Out:
#                         Simple Assault  Aggravated Assault  Robbery  Murder  \
# City Name         Year
# Seattle, WA       2020            5508                1632      607      37
# Dallas, TX        2020            5132                1069      217      26
# Indianapolis, IN  2020            3616                1162      435      62
# Cleveland, OH     2020            3128                 703      220      31
# San Francisco, CA 2020            2089                2172      463      42
# Virginia, MN      2020             710                 206       29       0
# Missoula, MT      2020             592                 170       20       4
#
#                         Manslaughter  \
# City Name         Year
# Seattle, WA       2020             4
# Dallas, TX        2020             5
# Indianapolis, IN  2020             7
# Cleveland, OH     2020             0
# San Francisco, CA 2020             3
# Virginia, MN      2020             4
# Missoula, MT      2020             0
#
# ...

# %%
#crime_df2021 = crime_df2021.drop('Agency', axis=1)
crime_df2017_group = crime_df2017.groupby(['City Name', 'Year']).sum().sort_values(ascending=False, by='Simple Assault')
crime_df2017_group
# Out:
#                         Simple Assault  Aggravated Assault  Robbery  Murder  \
# City Name         Year
# Seattle, WA       2017            5039                1464      668      28
# Dallas, TX        2017            5032                 925      266      32
# Indianapolis, IN  2017            3448                2225      781      71
# Cleveland, OH     2017            3189                 672      240      34
# San Francisco, CA 2017            2448                2677      603      44
# Virginia, MN      2017             851                 214       16       8
# Missoula, MT      2017             565                  93        8       2
#
#                         Manslaughter  \
# City Name         Year
# Seattle, WA       2017             1
# Dallas, TX        2017             2
# Indianapolis, IN  2017             4
# Cleveland, OH     2017             0
# San Francisco, CA 2017             3
# Virginia, MN      2017             1
# Missoula, MT      2017             0
#
# ...

# %%
seattle_df = crime_df2017[crime_df2017["City Name"] == "Seattle, WA"]["Simple Assault"]
dallas_df = crime_df2017[crime_df2017["City Name"] == "Dallas, TX"]["Simple Assault"]
indianapolis_df = crime_df2017[crime_df2017["City Name"] == "Indianapolis, IN"]["Simple Assault"]
cleveland_df = crime_df2017[crime_df2017["City Name"] == "Cleveland, OH"]["Simple Assault"]
san_fran_df = crime_df2017[crime_df2017["City Name"] == "San Francisco, CA"]["Simple Assault"]
virginia_df = crime_df2017[crime_df2017["City Name"] == "Virginia, MN"]["Simple Assault"]
missoula_df = crime_df2017[crime_df2017["City Name"] == "Missoula, MT"]["Simple Assault"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for simple assault in the year 2017 including all cities studied.")
# Out:
# The F statistic is 2.442350601616352 and the p-value is 0.027902046045055338 for simple assault in the year 2017 including all cities studied.

# %%
seattle_df = crime_df2017[crime_df2017["City Name"] == "Seattle, WA"]["Aggravated Assault"]
dallas_df = crime_df2017[crime_df2017["City Name"] == "Dallas, TX"]["Aggravated Assault"]
indianapolis_df = crime_df2017[crime_df2017["City Name"] == "Indianapolis, IN"]["Aggravated Assault"]
cleveland_df = crime_df2017[crime_df2017["City Name"] == "Cleveland, OH"]["Aggravated Assault"]
san_fran_df = crime_df2017[crime_df2017["City Name"] == "San Francisco, CA"]["Aggravated Assault"]
virginia_df = crime_df2017[crime_df2017["City Name"] == "Virginia, MN"]["Aggravated Assault"]
missoula_df = crime_df2017[crime_df2017["City Name"] == "Missoula, MT"]["Aggravated Assault"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for aggravated assault in the year 2017 including all cities studied.")
# Out:
# The F statistic is 3.3258754630470313 and the p-value is 0.004216296109450391 for aggravated assault in the year 2017 including all cities studied.

# %%
seattle_df = crime_df2017[crime_df2017["City Name"] == "Seattle, WA"]["Robbery"]
dallas_df = crime_df2017[crime_df2017["City Name"] == "Dallas, TX"]["Robbery"]
indianapolis_df = crime_df2017[crime_df2017["City Name"] == "Indianapolis, IN"]["Robbery"]
cleveland_df = crime_df2017[crime_df2017["City Name"] == "Cleveland, OH"]["Robbery"]
san_fran_df = crime_df2017[crime_df2017["City Name"] == "San Francisco, CA"]["Robbery"]
virginia_df = crime_df2017[crime_df2017["City Name"] == "Virginia, MN"]["Robbery"]
missoula_df = crime_df2017[crime_df2017["City Name"] == "Missoula, MT"]["Robbery"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for robbery in the year 2017 including all cities studied.")
# Out:
# The F statistic is 3.8607599750105672 and the p-value is 0.001312245742166794 for robbery in the year 2017 including all cities studied.

# %%
seattle_df = crime_df2017[crime_df2017["City Name"] == "Seattle, WA"]["Murder"]
dallas_df = crime_df2017[crime_df2017["City Name"] == "Dallas, TX"]["Murder"]
indianapolis_df = crime_df2017[crime_df2017["City Name"] == "Indianapolis, IN"]["Murder"]
cleveland_df = crime_df2017[crime_df2017["City Name"] == "Cleveland, OH"]["Murder"]
san_fran_df = crime_df2017[crime_df2017["City Name"] == "San Francisco, CA"]["Murder"]
virginia_df = crime_df2017[crime_df2017["City Name"] == "Virginia, MN"]["Murder"]
missoula_df = crime_df2017[crime_df2017["City Name"] == "Missoula, MT"]["Murder"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for murder in the year 2017 including all cities studied.")
# Out:
# The F statistic is 3.7290613839164726 and the p-value is 0.0017505436917966397 for murder in the year 2017 including all cities studied.

# %%
seattle_df = crime_df2017[crime_df2017["City Name"] == "Seattle, WA"]["Manslaughter"]
dallas_df = crime_df2017[crime_df2017["City Name"] == "Dallas, TX"]["Manslaughter"]
indianapolis_df = crime_df2017[crime_df2017["City Name"] == "Indianapolis, IN"]["Manslaughter"]
cleveland_df = crime_df2017[crime_df2017["City Name"] == "Cleveland, OH"]["Manslaughter"]
san_fran_df = crime_df2017[crime_df2017["City Name"] == "San Francisco, CA"]["Manslaughter"]
virginia_df = crime_df2017[crime_df2017["City Name"] == "Virginia, MN"]["Manslaughter"]
missoula_df = crime_df2017[crime_df2017["City Name"] == "Missoula, MT"]["Manslaughter"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for manslaughter in the year 2017 including all cities studied.")
# Out:
# The F statistic is 3.519129085295128 and the p-value is 0.002768654383495277 for manslaughter in the year 2017 including all cities studied.

# %%
# df labeled with 2021 but really data is representing 2020.
seattle_df = crime_df2021[crime_df2021["City Name"] == "Seattle, WA"]["Simple Assault"]
dallas_df = crime_df2021[crime_df2021["City Name"] == "Dallas, TX"]["Simple Assault"]
indianapolis_df = crime_df2021[crime_df2021["City Name"] == "Indianapolis, IN"]["Simple Assault"]
cleveland_df = crime_df2021[crime_df2021["City Name"] == "Cleveland, OH"]["Simple Assault"]
san_fran_df = crime_df2021[crime_df2021["City Name"] == "San Francisco, CA"]["Simple Assault"]
virginia_df = crime_df2021[crime_df2021["City Name"] == "Virginia, MN"]["Simple Assault"]
missoula_df = crime_df2021[crime_df2021["City Name"] == "Missoula, MT"]["Simple Assault"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for simple assault in the year 2020 including all cities studied.")
# Out:
# The F statistic is 1.8119466848687322 and the p-value is 0.09968805401943956 for simple assault in the year 2020 including all cities studied.

# %%
# df labeled with 2021 but really data is representing 2020.
seattle_df = crime_df2021[crime_df2021["City Name"] == "Seattle, WA"]["Aggravated Assault"]
dallas_df = crime_df2021[crime_df2021["City Name"] == "Dallas, TX"]["Aggravated Assault"]
indianapolis_df = crime_df2021[crime_df2021["City Name"] == "Indianapolis, IN"]["Aggravated Assault"]
cleveland_df = crime_df2021[crime_df2021["City Name"] == "Cleveland, OH"]["Aggravated Assault"]
san_fran_df = crime_df2021[crime_df2021["City Name"] == "San Francisco, CA"]["Aggravated Assault"]
virginia_df = crime_df2021[crime_df2021["City Name"] == "Virginia, MN"]["Aggravated Assault"]
missoula_df = crime_df2021[crime_df2021["City Name"] == "Missoula, MT"]["Aggravated Assault"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for aggravated assault in the year 2020 including all cities studied.")
# Out:
# The F statistic is 1.9215786747003472 and the p-value is 0.08018878572375646 for aggravated assault in the year 2020 including all cities studied.

# %%
# df labeled with 2021 but really data is representing 2020.
seattle_df = crime_df2021[crime_df2021["City Name"] == "Seattle, WA"]["Robbery"]
dallas_df = crime_df2021[crime_df2021["City Name"] == "Dallas, TX"]["Robbery"]
indianapolis_df = crime_df2021[crime_df2021["City Name"] == "Indianapolis, IN"]["Robbery"]
cleveland_df = crime_df2021[crime_df2021["City Name"] == "Cleveland, OH"]["Robbery"]
san_fran_df = crime_df2021[crime_df2021["City Name"] == "San Francisco, CA"]["Robbery"]
virginia_df = crime_df2021[crime_df2021["City Name"] == "Virginia, MN"]["Robbery"]
missoula_df = crime_df2021[crime_df2021["City Name"] == "Missoula, MT"]["Robbery"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for robbery in the year 2020 including all cities studied.")
# Out:
# The F statistic is 2.417513559255366 and the p-value is 0.028899586985838107 for robbery in the year 2020 including all cities studied.

# %%
# df labeled with 2021 but really data is representing 2020.
seattle_df = crime_df2021[crime_df2021["City Name"] == "Seattle, WA"]["Murder"]
dallas_df = crime_df2021[crime_df2021["City Name"] == "Dallas, TX"]["Murder"]
indianapolis_df = crime_df2021[crime_df2021["City Name"] == "Indianapolis, IN"]["Murder"]
cleveland_df = crime_df2021[crime_df2021["City Name"] == "Cleveland, OH"]["Murder"]
san_fran_df = crime_df2021[crime_df2021["City Name"] == "San Francisco, CA"]["Murder"]
virginia_df = crime_df2021[crime_df2021["City Name"] == "Virginia, MN"]["Murder"]
missoula_df = crime_df2021[crime_df2021["City Name"] == "Missoula, MT"]["Murder"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for murder in the year 2020 including all cities studied.")
# Out:
# The F statistic is 2.6789519603485528 and the p-value is 0.01658377294683144 for murder in the year 2020 including all cities studied.

# %%
# df labeled with 2021 but really data is representing 2020.
seattle_df = crime_df2021[crime_df2021["City Name"] == "Seattle, WA"]["Manslaughter"]
dallas_df = crime_df2021[crime_df2021["City Name"] == "Dallas, TX"]["Manslaughter"]
indianapolis_df = crime_df2021[crime_df2021["City Name"] == "Indianapolis, IN"]["Manslaughter"]
cleveland_df = crime_df2021[crime_df2021["City Name"] == "Cleveland, OH"]["Manslaughter"]
san_fran_df = crime_df2021[crime_df2021["City Name"] == "San Francisco, CA"]["Manslaughter"]
virginia_df = crime_df2021[crime_df2021["City Name"] == "Virginia, MN"]["Manslaughter"]
missoula_df = crime_df2021[crime_df2021["City Name"] == "Missoula, MT"]["Manslaughter"]
fval, pval = stats.f_oneway(seattle_df, dallas_df, indianapolis_df, cleveland_df, san_fran_df, virginia_df, missoula_df)
print(f"The F statistic is {fval} and the p-value is {pval} for murder in the year 2020 including all cities studied.")
# Out:
# The F statistic is 2.5936073689908707 and the p-value is 0.019900731026753382 for murder in the year 2020 including all cities studied.

# %%
# T-test 

# simple assault 
simple_assault_mean = stats.ttest_1samp(crime_df2017["Simple Assault"], crime_df2021["Simple Assault"].mean())
print(f"T-test resuls for simple assult in 2017 and 2020 include {simple_assault_mean}")

# aggravated assault 
agg_assault_mean = stats.ttest_1samp(crime_df2017["Aggravated Assault"], crime_df2021["Aggravated Assault"].mean())
print(f"T-test resuls for aggravated assult in 2017 and 2020 include {agg_assault_mean}")

# robbery 
robbery_mean = stats.ttest_1samp(crime_df2017["Robbery"], crime_df2021["Robbery"].mean())
print(f"T-test resuls for robbery in 2017 and 2020 include {robbery_mean}")

# murder
murder_mean = stats.ttest_1samp(crime_df2017["Murder"], crime_df2021["Murder"].mean())
print(f"T-test resuls for murder in 2017 and 2020 include {murder_mean}")

# manslaughter
manslaughter_mean = stats.ttest_1samp(crime_df2017["Manslaughter"], crime_df2021["Manslaughter"].mean())
print(f"T-test resuls for manslaughter in 2017 and 2020 include {manslaughter_mean}")
# Out:
# T-test resuls for simple assault in 2017 and 2020 include TtestResult(statistic=0.3673383541517043, pvalue=0.7138709618251482, df=154)
# T-test resuls for aggravated assault in 2017 and 2020 include TtestResult(statistic=0.6236669670510698, pvalue=0.5337689882162937, df=154)
# T-test resuls for robbery in 2017 and 2020 include TtestResult(statistic=0.8271378969434836, pvalue=0.4094387170996685, df=154)
# T-test resuls for murder in 2017 and 2020 include TtestResult(statistic=0.43758429604037385, pvalue=0.6623007303287021, df=154)
# T-test resuls for manslaughter in 2017 and 2020 include TtestResult(statistic=-1.9946155618253274, pvalue=0.047849517019395035, df=154)

# %%
base_url = 'https://api.usa.gov/crime/fbi/cde'
#arrest = 'arrest'
agencies = []
crime = ['violent_crime?', 'property_crime?']
#prop_crime = 'property_crime?'
year = ['from=2017&to=2017&', 'from=2021&to=2021&']
#from_to_2020= 'from=2020&to=2021&'
url = f"{base_url}/arrest/agency/{agencies}/{crime}{year}API_KEY={api_key}"
response = requests.get(url)
pprint(response.json())
# Out:
# {'data': [{'Arson': 0,
#            'Burglary': 20,
#            'Embezzlement': 0,
#            'Forgery and Counterfeiting': 8,
#            'Fraud': 2,
#            'Larceny - Theft': 84,
#            'Motor Vehicle Theft': 5,
#            'Stolen Property: Buying, Receiving, Possessing': 1,
#            'Vandalism': 17,
#            'data_year': 2017},
#           {'Arson': 0,
#            'Burglary': 12,
#            'Embezzlement': 0,
#            'Forgery and Counterfeiting': 6,
#            'Fraud': 5,
#            'Larceny - Theft': 107,
#            'Motor Vehicle Theft': 6,
#            'Stolen Property: Buying, Receiving, Possessing': 1,
#            'Vandalism': 16,
#            'data_year': 2018}],
#  'keys': ['Motor Vehicle Theft',
#           'Arson',
#           'Burglary',
#           'Embezzlement',
#           'Forgery and Counterfeiting',
#           'Fraud',
#           'Larceny - Theft',
#           'Vandalism',
# ...
