# %%
import pandas as pd
import json
import requests
import datetime
from pprint import pprint
from config import census_api_key
from census import Census
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np

# %%
c = Census(
    census_api_key,
    year = 2017
)

# %%
census_data_2017 = c.acs5.get(
    (
        "NAME",
        "B19013_001E",
        "B01003_001E",
        "B17001_002E",
        "B23025_005E"
    ),
    {'for': 'zip code tabulation area:*'}
)

# Convert to DataFrame
census_df_2017 = pd.DataFrame(census_data_2017)

# Column renaming
census_df_2017 = census_df_2017.rename(
    columns = {
        "B01003_001E": "Population",
        "B19013_001E": "Household Income",
        "B17001_002E": "Poverty Count",
        "B23025_005E": 'Unemployed',
        "NAME": "Name",
        "zip code tabulation area": "Zipcode"
    }
)

# Add a Poverty Rate column (Poverty Count / Population)
census_df_2017["Poverty Rate"] = 100 * census_df_2017["Poverty Count"].astype(int) / census_df_2017["Population"].astype(int)

# Configure the final DataFrame
census_df_2017 = census_df_2017[
    [
        "Zipcode",
        "Population",
        'Unemployed',
        "Household Income",
        "Poverty Count",
        "Poverty Rate",
        
    ]
]

# Display DataFrame length and sample data
print(f"Number of rows in the DataFrame: {len(census_df_2017)}")
census_df_2017.head()
# Out:
# Number of rows in the DataFrame: 33120
#   Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 0   00601     17599.0      2454.0           11757.0        11282.0
# 1   00602     39209.0      2538.0           16190.0        20428.0
# 2   00603     50135.0      3588.0           16645.0        25176.0
# 3   00606      6304.0       204.0           13387.0         4092.0
# 4   00610     27590.0      1474.0           18741.0        12553.0
#
#    Poverty Rate
# 0     64.105915
# 1     52.100283
# 2     50.216416
# 3     64.911168
# 4     45.498369

# %%
poverty_df_2017 = census_df_2017.sort_values(by='Poverty Count', ascending=False)
poverty_df_2017.head()
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 30019   90011    108051.0      3954.0           33824.0        38839.0
# 2645    10456     94667.0      5329.0           26724.0        37540.0
# 27256   78521     92975.0      3280.0           28935.0        34978.0
# 56      00725     82822.0      5766.0           20374.0        34629.0
# 2642    10453     82232.0      4555.0           24421.0        33803.0
#
#        Poverty Rate
# 30019     35.945063
# 2645      39.654790
# 27256     37.620866
# 56        41.811354
# 2642      41.106868

# %%
desired_zip_codes = ['98101', '98102', '98103', '98104', '98105', '98106', '98107', '98108', '98109', '98110', '98111', '98112', '98113', '98114', '98115', '98116', '98117', '98118', '98119', '98121', '98122', '98124', '98125', '98126', '98127', '98129', '98131', '98133','98136', '98138', '98139', '98141', '98144', '98145', '98146', '98148', '98155', '98160', '98161', '98165', '98166', '98168', '98170', '98175', '98177', '98178', '98181', '98185', '98188', '98190', '98191', '98194', '98198', '98199']

seattle_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

seattle_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 32342   98105     47128.0      2112.0           56015.0        11346.0
# 32352   98118     46800.0      2028.0           62504.0         9098.0
# 32358   98133     48390.0      1295.0           60409.0         6247.0
# 32355   98122     37270.0       897.0           72018.0         5835.0
# 32345   98108     24134.0      1241.0           55314.0         5562.0
# 32356   98125     40803.0      1298.0           61014.0         5499.0
# 32369   98168     31771.0      1355.0           53992.0         5381.0
# 32349   98115     51523.0      1159.0          100794.0         5081.0
# 32375   98198     37262.0      1114.0           59843.0         4948.0
# 32372   98178     27279.0       647.0           72478.0         4216.0
# 32361   98144     30850.0       779.0           71628.0         4021.0
# 32343   98106     26244.0      1232.0           62726.0         4017.0
# ...

# %%
seattle_df_2017 = seattle_df_2017.dropna()

# %%
numeric_columns_seattle_2017 = seattle_df_2017.select_dtypes(include='number')
seattle_stats_data_2017 = numeric_columns_seattle_2017.mean()
seattle_std_data_2017 = numeric_columns_seattle_2017.std(skipna=True)

seattle_stats_2017 = pd.DataFrame(seattle_stats_data_2017).transpose()
seattle_stats_2017.index = ['Seattle 2017']

seattle_std_2017 = pd.DataFrame(seattle_std_data_2017).transpose()
seattle_std_2017.index = ['Seattle Std Dev 2017']

seattle_stats_2017 = pd.concat([seattle_stats_2017, seattle_std_2017])

seattle_stats_2017
# Out:
#                         Population  Unemployed  Household Income  \
# Seattle 2017          28928.090909  858.212121      77262.303030
# Seattle Std Dev 2017  11010.669928  448.999566      19789.763898
#
#                       Poverty Count  Poverty Rate
# Seattle 2017            3516.787879     11.923184
# Seattle Std Dev 2017    2372.587838      5.520457

# %%
desired_zip_codes = ["75001", "75006", "75007", "75019", "75032", "75039", "75041", "75042", "75043", "75050", "75051", "75052", "75061",
          "75062", "75063", "75080", "75081", "75087", "75088", "75089", "75093", "75098", "75104", "75115", "75116", "75126",
          "75134", "75149", "75150", "75159", "75166", "75180", "75181", "75182", "75201", "75202", "75203", "75204", "75205",
          "75206", "75207", "75208", "75209", "75210", "75211", "75212", "75214", "75215", "75216", "75217", "75218", "75219",
          "75220", "75221", "75222", "75223", "75224", "75225", "75226", "75227", "75228", "75229", "75230", "75231", "75232",
          "75233", "75234", "75235", "75236", "75237", "75238", "75240", "75241", "75242", "75243", "75244", "75246", "75247",
          "75248", "75249", "75250", "75251", "75252", "75253", "75254", "75260", "75261", "75262", "75263", "75264", "75265",
          "75266", "75267", "75270", "75275", "75277", "75283", "75284", "75285", "75287", "75301", "75303", "75312", "75313",
          "75315", "75320", "75326", "75336", "75339", "75342", "75354", "75355", "75356", "75357", "75358", "75359", "75360",
          "75367", "75368", "75370", "75371", "75372", "75373", "75374", "75376", "75378", "75379", "75380", "75381", "75382",
          "75389", "75390", "75391", "75392", "75393", "75394", "75395", "75397", "75398"]

dallas_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

dallas_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 25984   75217     85249.0      1358.0           35282.0        26496.0
# 25983   75216     52895.0      1834.0           25763.0        19585.0
# 25979   75211     77600.0      2219.0           38760.0        19107.0
# 26006   75243     67445.0      2432.0           38640.0        17188.0
# 25993   75228     74605.0      2636.0           40306.0        16217.0
# ...       ...         ...         ...               ...            ...
# 25975   75207      8028.0         8.0           79926.0          150.0
# 25967   75182      6077.0       166.0          137721.0          139.0
# 25960   75166      4057.0        36.0           91136.0           19.0
# 26018   75390         0.0         0.0      -666666666.0            0.0
# 26016   75270         0.0         0.0      -666666666.0            0.0
#
#        Poverty Rate
# 25984     31.080716
# 25983     37.026184
# 25979     24.622423
# 26006     25.484469
# ...

# %%
dallas_df_2017 = dallas_df_2017.dropna()

# %%
numeric_columns_dallas_2017 = dallas_df_2017.select_dtypes(include='number')
dallas_stats_data_2017 = numeric_columns_dallas_2017.mean()
dallas_std_data_2017 = numeric_columns_dallas_2017.std(skipna=True)

dallas_stats_2017 = pd.DataFrame(dallas_stats_data_2017).transpose()
dallas_stats_2017.index = ['Dallas 2017']

dallas_std_2017 = pd.DataFrame(dallas_std_data_2017).transpose()
dallas_std_2017.index = ['Dallas Std Dev 2017']

dallas_stats_2017 = pd.concat([dallas_stats_2017, dallas_std_2017])

dallas_stats_2017
# Out:
#                        Population  Unemployed  Household Income  \
# Dallas 2017          32953.134146  988.304878      62511.548780
# Dallas Std Dev 2017  19615.540120  649.245045      28061.532142
#
#                      Poverty Count  Poverty Rate
# Dallas 2017            5436.743902     17.122951
# Dallas Std Dev 2017    4892.123601     11.045396

# %%
desired_zip_codes = ["94101", "94102", "94103", "94104", "94105", "94107", "94108", "94109", "94110", "94111", "94112", "94114",
                 "94115", "94116", "94117", "94118", "94119", "94120", "94121", "94122", "94123", "94124", "94125", "94126",
                 "94127", "94129", "94130", "94131", "94132", "94133", "94134", "94140", "94141", "94142", "94146", "94147",
                 "94157", "94159", "94164", "94165", "94166", "94167", "94168", "94169", "94170", "94172", "94188"]

sanfransisco_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

sanfransisco_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 30985   94112     85373.0      3409.0           82692.0         7750.0
# 30994   94124     35492.0      1854.0           55823.0         7529.0
# 30983   94110     73737.0      2728.0          109747.0         7321.0
# 30976   94102     30140.0      1045.0           33552.0         6957.0
# 30982   94109     56587.0      1610.0           79979.0         6718.0
# 30992   94122     62516.0      1570.0          102838.0         5924.0
# 30977   94103     26990.0       762.0           49052.0         5870.0
# 31000   94132     31155.0      1874.0           72970.0         5124.0
# 31002   94134     43074.0      1845.0           71352.0         5048.0
# 30987   94115     35751.0      1128.0          103625.0         4531.0
# 31001   94133     26942.0       921.0           66422.0         4314.0
# 30988   94116     47708.0      1600.0          101746.0         4006.0
# ...

# %%
sanfransisco_df_2017 = sanfransisco_df_2017.dropna()

# %%
numeric_columns_sanfransisco_2017 = sanfransisco_df_2017.select_dtypes(include='number')
sanfransisco_stats_data_2017 = numeric_columns_sanfransisco_2017.mean()
sanfransisco_std_data_2017 = numeric_columns_sanfransisco_2017.std(skipna=True)

sanfransisco_stats_2017 = pd.DataFrame(sanfransisco_stats_data_2017).transpose()
sanfransisco_stats_2017.index = ['Sanfransisco 2017']

sanfransisco_std_2017 = pd.DataFrame(sanfransisco_std_data_2017).transpose()
sanfransisco_std_2017.index = ['Sanfransisco Std Dev 2017']

sanfransisco_stats_2017 = pd.concat([sanfransisco_stats_2017, sanfransisco_std_2017])

sanfransisco_stats_2017
# Out:
#                              Population   Unemployed  Household Income  \
# Sanfransisco 2017          32988.153846  1111.076923      99611.653846
# Sanfransisco Std Dev 2017  21364.040838   823.142949      43221.162092
#
#                            Poverty Count  Poverty Rate
# Sanfransisco 2017            3774.115385     13.602770
# Sanfransisco Std Dev 2017    2428.532352      9.457921

# %%
desired_zip_codes = ["44102", "44103", "44104", "44105", "44106", "44107", "44108", "44109", "44110", "44111", "44112", "44113",
             "44114", "44115", "44117", "44118", "44119", "44120", "44121", "44124", "44125", "44126", "44127", "44128", "44129",
             "44130", "44134", "44135", "44137", "44142", "44143", "44144", "44181", "44188", "44190", "44191", "44192" ,"44193",
             "44194", "44195", "44197", "44198", "44199"]

cleveland_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

cleveland_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 14213   44102     45276.0      2527.0           29909.0        16315.0
# 14216   44105     38018.0      3726.0           25057.0        14715.0
# 14220   44109     40810.0      2622.0           30464.0        12831.0
# 14215   44104     20541.0      2613.0           14646.0        11954.0
# 14231   44120     34556.0      2580.0           33936.0         8452.0
# 14219   44108     22048.0      2449.0           24078.0         8299.0
# 14222   44111     41455.0      1978.0           40542.0         8252.0
# 14217   44106     25836.0      1375.0           25892.0         8183.0
# 14223   44112     21788.0      1683.0           22147.0         8182.0
# 14221   44110     19614.0      1879.0           21468.0         7845.0
# 14218   44107     50954.0      1730.0           48671.0         7425.0
# 14246   44135     27826.0      1565.0           37408.0         7408.0
# ...

# %%
cleveland_df_2017 = cleveland_df_2017.dropna()

# %%
numeric_columns_cleveland_2017 = cleveland_df_2017.select_dtypes(include='number')
cleveland_stats_data_2017 = numeric_columns_cleveland_2017.mean()
cleveland_std_data_2017 = numeric_columns_cleveland_2017.std(skipna=True)

cleveland_stats_2017 = pd.DataFrame(cleveland_stats_data_2017).transpose()
cleveland_stats_2017.index = ['Cleveland 2017']

cleveland_std_2017 = pd.DataFrame(cleveland_std_data_2017).transpose()
cleveland_std_2017.index = ['Cleveland Std Dev 2017']

cleveland_stats_2017 = pd.concat([cleveland_stats_2017, cleveland_std_2017])

cleveland_stats_2017
# Out:
#                          Population  Unemployed  Household Income  \
# Cleveland 2017          26683.75000  1473.50000      37463.125000
# Cleveland Std Dev 2017  12349.39717   790.67562      14503.969828
#
#                         Poverty Count  Poverty Rate
# Cleveland 2017            6166.937500     26.240029
# Cleveland Std Dev 2017    3766.234681     14.991650

# %%
desired_zip_codes = ["59801", "59802", "59803", "59804", "59806", "59807", "59808"]

missoula_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

missoula_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 20342   59801     32067.0      1457.0           36606.0         7821.0
# 20343   59802     19376.0       850.0           41039.0         3619.0
# 20346   59808     19403.0       536.0           56084.0         2316.0
# 20344   59803     17318.0       335.0           68183.0         1336.0
# 20345   59804      8229.0       246.0           60094.0          918.0
#
#        Poverty Rate
# 20342     24.389559
# 20343     18.677746
# 20346     11.936299
# 20344      7.714517
# 20345     11.155669

# %%
missoula_df_2017 = missoula_df_2017.dropna()

# %%
numeric_columns_missoula_2017 = missoula_df_2017.select_dtypes(include='number')
missoula_stats_data_2017 = numeric_columns_missoula_2017.mean()
missoula_std_data_2017 = numeric_columns_missoula_2017.std(skipna=True)

missoula_stats_2017 = pd.DataFrame(missoula_stats_data_2017).transpose()
missoula_stats_2017.index = ['Missoula 2017']

missoula_std_2017 = pd.DataFrame(missoula_std_data_2017).transpose()
missoula_std_2017.index = ['Missoula Std Dev 2017']

missoula_stats_2017 = pd.concat([missoula_stats_2017, missoula_std_2017])

missoula_stats_2017
# Out:
#                          Population  Unemployed  Household Income  \
# Missoula 2017          19278.600000  684.800000      52401.200000
# Missoula Std Dev 2017   8507.434237  490.058874      13232.491553
#
#                        Poverty Count  Poverty Rate
# Missoula 2017            3202.000000     14.774758
# Missoula Std Dev 2017    2783.552496      6.683550

# %%
desired_zip_codes = ['55792']

virginia_minnesota_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

# Assuming virginia_minnesota_df is your original DataFrame
numeric_columns_2017 = virginia_minnesota_df_2017.select_dtypes(include='number')
virginia_stats_data_2017 = numeric_columns_2017.mean()
virginia_std_data_2017 = numeric_columns_2017.std(skipna=True)  # Set skipna=True to exclude NaN values

# Create the DataFrame with mean statistics
virginia_stats_2017 = pd.DataFrame(virginia_stats_data_2017).transpose()
virginia_stats_2017.index = ['Virginia Minnesota 2017']

# Concatenate the two DataFrames vertically to add the second row
virginia_stats_2017 = pd.concat([virginia_stats_2017])

# Display the final DataFrame
virginia_stats_2017
# Out:
#                          Population  Unemployed  Household Income  \
# Virginia Minnesota 2017      9795.0       261.0           39080.0
#
#                          Poverty Count  Poverty Rate
# Virginia Minnesota 2017         2054.0     20.969883

# %%
desired_zip_codes = ["46107", "46201", "46202", "46203", "46204", "46205", "46206", "46207", "46208", "46214", "46214", "46216",
      "46217", "46217", "46218", "46219", "46220", "46221", "46222", "46224", "46224", "46225", "46226", "46226", "46227",
      "46227", "46228", "46229", "46229", "46230", "46231", "46231", "46234", "46234", "46235", "46235", "46236", "46236",
      "46237", "46237", "46239", "46239", "46240", "46240", "46241", "46241", "46242", "46244", "46247", "46247", "46250",
      "46250", "46251", "46253", "46253" ,"46254", "46254", "46256", "46256", "46259", "46259", "46260", "46260", "46268",
      "46268", "46278", "46278", "46282"]

indianapolis_df_2017 = poverty_df_2017[poverty_df_2017['Zipcode'].isin(desired_zip_codes)]

indianapolis_df_2017
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 15064   46222     36508.0      1449.0           30821.0        12518.0
# 15067   46226     45468.0      3523.0           33348.0        12153.0
# 15065   46224     36881.0      1478.0           35384.0        11687.0
# 15053   46203     39250.0      1711.0           35292.0        10809.0
# 15068   46227     57023.0      1630.0           40415.0        10746.0
# 15051   46201     29852.0      2181.0           28783.0        10270.0
# 15060   46218     26757.0      2038.0           23771.0        10086.0
# 15078   46241     31610.0      1585.0           36090.0         9654.0
# 15073   46235     32578.0      2118.0           36328.0         9233.0
# 15080   46254     40259.0      1778.0           43721.0         7609.0
# 15061   46219     37284.0      1710.0           39329.0         7431.0
# 15055   46205     28380.0      1641.0           41773.0         7064.0
# ...

# %%
indianapolis_df_2017 = indianapolis_df_2017.dropna()

# %%
desired_zip_codes = ["46107", "46183", "46201", "46202", "46203", "46204", "46205", "46206", "46207", "46208", "46214", "46214", "46216",
      "46217", "46217", "46218", "46219", "46220", "46221", "46222", "46224", "46224", "46225", "46226", "46226", "46227",
      "46227", "46228", "46229", "46229", "46230", "46231", "46231", "46234", "46234", "46235", "46235", "46236", "46236",
      "46237", "46237", "46239", "46239", "46240", "46240", "46241", "46241", "46242", "46244", "46247", "46247", "46250",
      "46250", "46251", "46253", "46253" ,"46254", "46254", "46256", "46256", "46259", "46259", "46260", "46260", "46268",
      "46268", "46278", "46278", "46282"]
poverty_rate = indianapolis_df_2017['Poverty Rate']
unemployed = indianapolis_df_2017['Unemployed']

plt.scatter(poverty_rate, unemployed, c='red', alpha=0.7)
plt.title('Poverty Rate vs Unemployed Individuals in Indianapolis')
plt.xlabel('Poverty Rate')
plt.ylabel('Unemployed')
plt.grid(True)

plt.show()

# %%
numeric_columns_indy_2017 = indianapolis_df_2017.select_dtypes(include='number')
indy_stats_data_2017 = numeric_columns_indy_2017.mean()
indy_std_data_2017 = numeric_columns_indy_2017.std(skipna=True)  # Set skipna=True to exclude NaN values

indy_stats_2017 = pd.DataFrame(indy_stats_data_2017).transpose()
indy_stats_2017.index = ['Indianapolis 2017']

indy_std_2017 = pd.DataFrame(indy_std_data_2017).transpose()
indy_std_2017.index = ['Indy Std Dev 2017']

indy_stats_2017 = pd.concat([indy_stats_2017, indy_std_2017])

indy_stats_2017
# Out:
#                      Population   Unemployed  Household Income  Poverty Count  \
# Indianapolis 2017  26490.222222  1087.055556      50769.527778    5070.083333
# Indy Std Dev 2017  12050.867189   729.706279      19763.152710    3954.195250
#
#                    Poverty Rate
# Indianapolis 2017     17.588272
# Indy Std Dev 2017      9.985247

# %%
combined_stats_2017 = pd.concat([cleveland_stats_2017, dallas_stats_2017, indy_stats_2017, missoula_stats_2017, sanfransisco_stats_2017, seattle_stats_2017, virginia_stats_2017])
combined_stats_2017
# Out:
#                              Population   Unemployed  Household Income  \
# Cleveland 2017             26683.750000  1473.500000      37463.125000
# Cleveland Std Dev 2017     12349.397170   790.675620      14503.969828
# Dallas 2017                32953.134146   988.304878      62511.548780
# Dallas Std Dev 2017        19615.540120   649.245045      28061.532142
# Indianapolis 2017          26490.222222  1087.055556      50769.527778
# Indy Std Dev 2017          12050.867189   729.706279      19763.152710
# Missoula 2017              19278.600000   684.800000      52401.200000
# Missoula Std Dev 2017       8507.434237   490.058874      13232.491553
# Sanfransisco 2017          32988.153846  1111.076923      99611.653846
# Sanfransisco Std Dev 2017  21364.040838   823.142949      43221.162092
# Seattle 2017               28928.090909   858.212121      77262.303030
# Seattle Std Dev 2017       11010.669928   448.999566      19789.763898
# ...

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia Minnesota']
poverty_rates = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]

# Create bar plot
plt.bar(cities, poverty_rates, color='blue')
plt.xlabel('City')
plt.ylabel('Poverty Rate')
plt.title('Poverty Rates for Cities (2017)')
plt.ylim(0, 30)  # Set the y-axis range if needed
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization

# Show plot
plt.show()

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia(MN)']
poverty_rates = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]

# Create line plot
plt.plot(cities, poverty_rates, marker='o', linestyle='-', color='green')
plt.title('Poverty in Different Cities (2017)')
plt.xlabel('City')
plt.ylabel('Poverty Rates')

# Show plot
plt.show()

# %%
c = Census(
    census_api_key,
    year = 2020
)

# %%
census_data = c.acs5.get(
    (
        "NAME",
        "B19013_001E",
        "B01003_001E",
        "B17001_002E",
        "B23025_005E"
    ),
    {'for': 'zip code tabulation area:*'}
)

# Convert to DataFrame
census_df = pd.DataFrame(census_data)

# Column renaming
census_df = census_df.rename(
    columns = {
        "B01003_001E": "Population",
        "B19013_001E": "Household Income",
        "B17001_002E": "Poverty Count",
        "B23025_005E": "Unemployed",
        "NAME": "Name",
        "zip code tabulation area": "Zipcode"
    }
)

# Add a Poverty Rate column (Poverty Count / Population)
census_df["Poverty Rate"] = 100 * census_df["Poverty Count"].astype(int) / census_df["Population"].astype(int)

# Configure the final DataFrame
census_df = census_df[
    [
        "Zipcode",
        "Population",
        'Unemployed',
        "Household Income",
        "Poverty Count",
        "Poverty Rate"
        
    ]
]

# Display DataFrame length and sample data
print(f"Number of rows in the DataFrame: {len(census_df)}")
census_df.head()
# Out:
# Number of rows in the DataFrame: 33120
#   Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 0   29590      3543.0        46.0           30985.0          869.0
# 1   93306     74296.0      2379.0           54450.0        15853.0
# 2   93660      4082.0       229.0           39625.0         1057.0
# 3   93110     15777.0       286.0           93264.0         1332.0
# 4   93212     22596.0       575.0           42983.0         3911.0
#
#    Poverty Rate
# 0     24.527237
# 1     21.337622
# 2     25.894170
# 3      8.442670
# 4     17.308373

# %%
poverty_df = census_df.sort_values(by='Poverty Count', ascending=False)
poverty_df.head()
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 24541   00725     79395.0      4910.0           22847.0        32123.0
# 27737   10456     90479.0      5051.0           31645.0        31939.0
# 14537   11219     87812.0      2043.0           41907.0        30784.0
# 24188   78521     89629.0      2686.0           33616.0        30062.0
# 6604    11206     87599.0      3835.0           43065.0        30051.0
#
#        Poverty Rate
# 24541     40.459727
# 27737     35.299904
# 14537     35.056712
# 24188     33.540484
# 6604      34.305186

# %%
desired_zip_codes = ['44145', '75206', '55792', '98101', '44312', '79735']

filtered_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

filtered_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 19004   75206     39653.0       744.0           75569.0         4692.0
# 594     44312     31887.0       987.0           53594.0         3014.0
# 713     55792      9689.0       268.0           44213.0         2124.0
# 24653   79735     13636.0        55.0           51838.0         2041.0
# 29660   98101     14380.0       299.0           91550.0         1652.0
# 24121   44145     32154.0       727.0           92917.0         1525.0
#
#        Poverty Rate
# 19004     11.832648
# 594        9.452128
# 713       21.921767
# 24653     14.967732
# 29660     11.488178
# 24121      4.742800

# %%
desired_zip_codes = ['98101', '98102', '98103', '98104', '98105', '98106', '98107', '98108', '98109', '98110', '98111', '98112', '98113', '98114', '98115', '98116', '98117', '98118', '98119', '98121', '98122', '98124', '98125', '98126', '98127', '98129', '98131', '98133','98136', '98138', '98139', '98141', '98144', '98145', '98146', '98148', '98155', '98160', '98161', '98165', '98166', '98168', '98170', '98175', '98177', '98178', '98181', '98185', '98188', '98190', '98191', '98194', '98198', '98199']

seattle_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

seattle_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 538     98105     52290.0      1585.0           67449.0        10977.0
# 678     98118     49702.0      1323.0           85541.0         6489.0
# 2195    98122     41152.0      1517.0           81308.0         5938.0
# 29659   98133     49476.0       900.0           73702.0         4697.0
# 2189    98125     44030.0      1204.0           78263.0         4627.0
# 22000   98108     24034.0       826.0           62530.0         4371.0
# 22065   98168     33217.0      1333.0           66237.0         4200.0
# 10895   98103     54194.0      1073.0          105480.0         3980.0
# 7973    98115     55519.0      1249.0          117038.0         3979.0
# 540     98146     27622.0       588.0           80633.0         3935.0
# 29661   98106     27997.0       761.0           74608.0         3765.0
# 2196    98198     38699.0      1318.0           66938.0         3604.0
# ...

# %%
seattle_df = seattle_df.dropna()

# %%
numeric_columns_seattle = seattle_df.select_dtypes(include='number')
seattle_stats_data = numeric_columns_seattle.mean()
seattle_std_data = numeric_columns_seattle.std(skipna=True)

seattle_stats = pd.DataFrame(seattle_stats_data).transpose()
seattle_stats.index = ['Seattle']

seattle_std = pd.DataFrame(seattle_std_data).transpose()
seattle_std.index = ['Seattle Std Dev']

seattle_stats = pd.concat([seattle_stats, seattle_std])

seattle_stats
# Out:
#                    Population  Unemployed  Household Income  Poverty Count  \
# Seattle          30698.090909  814.030303      93888.757576    3007.757576
# Seattle Std Dev  11795.062975  357.515427      22924.554596    2040.324010
#
#                  Poverty Rate
# Seattle              9.685197
# Seattle Std Dev      4.423470

# %%
desired_zip_codes = ["75001", "75006", "75007", "75019", "75032", "75039", "75041", "75042", "75043", "75050", "75051", "75052", "75061",
          "75062", "75063", "75080", "75081", "75087", "75088", "75089", "75093", "75098", "75104", "75115", "75116", "75126",
          "75134", "75149", "75150", "75159", "75166", "75180", "75181", "75182", "75201", "75202", "75203", "75204", "75205",
          "75206", "75207", "75208", "75209", "75210", "75211", "75212", "75214", "75215", "75216", "75217", "75218", "75219",
          "75220", "75221", "75222", "75223", "75224", "75225", "75226", "75227", "75228", "75229", "75230", "75231", "75232",
          "75233", "75234", "75235", "75236", "75237", "75238", "75240", "75241", "75242", "75243", "75244", "75246", "75247",
          "75248", "75249", "75250", "75251", "75252", "75253", "75254", "75260", "75261", "75262", "75263", "75264", "75265",
          "75266", "75267", "75270", "75275", "75277", "75283", "75284", "75285", "75287", "75301", "75303", "75312", "75313",
          "75315", "75320", "75326", "75336", "75339", "75342", "75354", "75355", "75356", "75357", "75358", "75359", "75360",
          "75367", "75368", "75370", "75371", "75372", "75373", "75374", "75376", "75378", "75379", "75380", "75381", "75382",
          "75389", "75390", "75391", "75392", "75393", "75394", "75395", "75397", "75398"]

dallas_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

dallas_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 21889   75217     86811.0      1146.0           41513.0        24419.0
# 32973   75211     77920.0      1790.0           46226.0        16840.0
# 21888   75216     54253.0      1707.0           29448.0        16405.0
# 11543   75228     75303.0      2179.0           46061.0        15681.0
# 4343    75243     68253.0      2137.0           44542.0        13790.0
# ...       ...         ...         ...               ...            ...
# 32489   75251      3750.0        52.0           75769.0          172.0
# 32486   75202      2739.0       104.0           92500.0          170.0
# 20506   75166      4624.0        38.0          101150.0           97.0
# 15913   75390         0.0         0.0      -666666666.0            0.0
# 20515   75270         0.0         0.0      -666666666.0            0.0
#
#        Poverty Rate
# 21889     28.128924
# 32973     21.611910
# 21888     30.237959
# 11543     20.823872
# ...

# %%
dallas_df = dallas_df.dropna()

# %%
numeric_columns_dallas = dallas_df.select_dtypes(include='number')
dallas_stats_data = numeric_columns_dallas.mean()
dallas_std_data = numeric_columns_dallas.std(skipna=True)

dallas_stats = pd.DataFrame(dallas_stats_data).transpose()
dallas_stats.index = ['Dallas']

dallas_std = pd.DataFrame(dallas_std_data).transpose()
dallas_std.index = ['Dallas Std Dev']

dallas_stats = pd.concat([dallas_stats, dallas_std])

dallas_stats
# Out:
#                   Population  Unemployed  Household Income  Poverty Count  \
# Dallas          34036.292683  875.743902      70395.439024    4605.719512
# Dallas Std Dev  19905.006869  568.097297      29222.360059    4247.912531
#
#                 Poverty Rate
# Dallas             14.226568
# Dallas Std Dev     10.913720

# %%
desired_zip_codes = ["94101", "94102", "94103", "94104", "94105", "94107", "94108", "94109", "94110", "94111", "94112", "94114",
                 "94115", "94116", "94117", "94118", "94119", "94120", "94121", "94122", "94123", "94124", "94125", "94126",
                 "94127", "94129", "94130", "94131", "94132", "94133", "94134", "94140", "94141", "94142", "94146", "94147",
                 "94157", "94159", "94164", "94165", "94166", "94167", "94168", "94169", "94170", "94172", "94188"]

sanfransisco_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

sanfransisco_df = sanfransisco_df.dropna()

sanfransisco_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 23228   94112     85053.0      2164.0          105340.0         7190.0
# 23193   94109     55797.0      1845.0           98567.0         6591.0
# 23227   94110     72765.0      2255.0          138890.0         6550.0
# 28916   94102     33264.0      1440.0           53539.0         6015.0
# 23195   94124     36278.0      1526.0           67094.0         5907.0
# 23209   94103     31585.0       684.0           87587.0         5687.0
# 26456   94122     61248.0      1797.0          122144.0         5225.0
# 29468   94134     43286.0      1487.0           82810.0         4798.0
# 28922   94121     43843.0      1022.0          107158.0         4493.0
# 23229   94132     30437.0      1642.0           82557.0         4045.0
# 23197   94133     26930.0      1050.0           68423.0         3785.0
# 23194   94115     33841.0       769.0          125550.0         3546.0
# ...

# %%
numeric_columns_sanfransisco = sanfransisco_df.select_dtypes(include='number')
sanfransisco_stats_data = numeric_columns_sanfransisco.mean()
sanfransisco_std_data = numeric_columns_sanfransisco.std(skipna=True)

sanfransisco_stats = pd.DataFrame(sanfransisco_stats_data).transpose()
sanfransisco_stats.index = ['Sanfransisco']

sanfransisco_std = pd.DataFrame(sanfransisco_std_data).transpose()
sanfransisco_std.index = ['Sanfransisco Std Dev']

sanfransisco_stats = pd.concat([sanfransisco_stats, sanfransisco_std])

sanfransisco_stats
# Out:
#                         Population  Unemployed  Household Income  \
# Sanfransisco          33290.500000  979.846154     122571.807692
# Sanfransisco Std Dev  20869.592911  647.706952      50897.949615
#
#                       Poverty Count  Poverty Rate
# Sanfransisco            3312.769231     11.720724
# Sanfransisco Std Dev    2180.296811      8.345049

# %%
desired_zip_codes = ["44102", "44103", "44104", "44105", "44106", "44107", "44108", "44109", "44110", "44111", "44112", "44113",
             "44114", "44115", "44117", "44118", "44119", "44120", "44121", "44124", "44125", "44126", "44127", "44128", "44129",
             "44130", "44134", "44135", "44137", "44142", "44143", "44144", "44181", "44188", "44190", "44191", "44192" ,"44193",
             "44194", "44195", "44197", "44198", "44199"]

cleveland_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

cleveland_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 16035   44102     44320.0      2276.0           32289.0        14742.0
# 17359   44105     35238.0      2753.0           31248.0        11673.0
# 24115   44104     19295.0      1478.0           16650.0        10361.0
# 17362   44109     39451.0      2249.0           35987.0        10194.0
# 16037   44111     42591.0      1931.0           45425.0         9238.0
# 24117   44120     35046.0      1506.0           37733.0         7904.0
# 11754   44135     27732.0      1388.0           39768.0         7422.0
# 16036   44110     18829.0      1122.0           25244.0         6958.0
# 17360   44106     25658.0      1132.0           30669.0         6841.0
# 24116   44108     22234.0      1571.0           27325.0         6807.0
# 20418   44112     21251.0      1344.0           26236.0         6727.0
# 17553   44128     28588.0      1884.0           36847.0         6510.0
# ...

# %%
cleveland_df = cleveland_df.dropna()

# %%
numeric_columns_cleveland = cleveland_df.select_dtypes(include='number')
cleveland_stats_data = numeric_columns_cleveland.mean()
cleveland_std_data = numeric_columns_cleveland.std(skipna=True)

cleveland_stats = pd.DataFrame(cleveland_stats_data).transpose()
cleveland_stats.index = ['Cleveland']

cleveland_std = pd.DataFrame(cleveland_std_data).transpose()
cleveland_std.index = ['Cleveland Std Dev']

cleveland_stats = pd.concat([cleveland_stats, cleveland_std])

cleveland_stats
# Out:
#                      Population   Unemployed  Household Income  Poverty Count  \
# Cleveland          26323.500000  1201.187500      42551.031250    5619.312500
# Cleveland Std Dev  12060.999472   591.753787      15205.223579    3192.346386
#
#                    Poverty Rate
# Cleveland             24.015054
# Cleveland Std Dev     13.260565

# %%
desired_zip_codes = ["59801", "59802", "59803", "59804", "59806", "59807", "59808"]

missoula_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

missoula_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 12791   59801     33427.0      1331.0           41722.0         7080.0
# 12798   59802     20778.0       820.0           52016.0         3348.0
# 12799   59808     20165.0       366.0           63033.0         1754.0
# 30521   59803     18156.0       425.0           80582.0         1198.0
# 13351   59804      8072.0       112.0           74034.0          506.0
#
#        Poverty Rate
# 12791     21.180483
# 12798     16.113197
# 12799      8.698240
# 30521      6.598370
# 13351      6.268583

# %%
missoula_df = missoula_df.dropna()

# %%
numeric_columns_missoula = missoula_df.select_dtypes(include='number')
missoula_stats_data = numeric_columns_missoula.mean()
missoula_std_data = numeric_columns_missoula.std(skipna=True)

missoula_stats = pd.DataFrame(missoula_stats_data).transpose()
missoula_stats.index = ['Missoula']

missoula_std = pd.DataFrame(missoula_std_data).transpose()
missoula_std.index = ['Missoula Std Dev']

missoula_stats = pd.concat([missoula_stats, missoula_std])

missoula_stats
# Out:
#                     Population  Unemployed  Household Income  Poverty Count  \
# Missoula          20119.600000  610.800000      62277.400000     2777.20000
# Missoula Std Dev   9034.971461  475.842096      15824.567571     2623.88361
#
#                   Poverty Rate
# Missoula             11.771774
# Missoula Std Dev      6.592943

# %%
desired_zip_codes = ['55792']

virginia_minnesota_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

virginia_minnesota_df
# Out:
#     Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 713   55792      9689.0       268.0           44213.0         2124.0
#
#      Poverty Rate
# 713     21.921767

# %%
# Assuming virginia_minnesota_df is your original DataFrame
numeric_columns = virginia_minnesota_df.select_dtypes(include='number')
virginia_stats_data = numeric_columns.mean()
virginia_std_data = numeric_columns.std(skipna=True)  # Set skipna=True to exclude NaN values

# Create the DataFrame with mean statistics
virginia_stats = pd.DataFrame(virginia_stats_data).transpose()
virginia_stats.index = ['Virginia Minnesota']

# Concatenate the two DataFrames vertically to add the second row
virginia_stats = pd.concat([virginia_stats])

# Display the final DataFrame
virginia_stats
# Out:
#                     Population  Unemployed  Household Income  Poverty Count  \
# Virginia Minnesota      9689.0       268.0           44213.0         2124.0
#
#                     Poverty Rate
# Virginia Minnesota     21.921767

# %%
desired_zip_codes = ["46107", "46183", "46201", "46202", "46203", "46204", "46205", "46206", "46207", "46208", "46214", "46214", "46216",
      "46217", "46217", "46218", "46219", "46220", "46221", "46222", "46224", "46224", "46225", "46226", "46226", "46227",
      "46227", "46228", "46229", "46229", "46230", "46231", "46231", "46234", "46234", "46235", "46235", "46236", "46236",
      "46237", "46237", "46239", "46239", "46240", "46240", "46241", "46241", "46242", "46244", "46247", "46247", "46250",
      "46250", "46251", "46253", "46253" ,"46254", "46254", "46256", "46256", "46259", "46259", "46260", "46260", "46268",
      "46268", "46278", "46278", "46282"]

indianapolis_df = poverty_df[poverty_df['Zipcode'].isin(desired_zip_codes)]

indianapolis_df
# Out:
#       Zipcode  Population  Unemployed  Household Income  Poverty Count  \
# 13918   46226     46718.0      2265.0           36688.0        11796.0
# 13916   46222     38629.0      1628.0           38110.0        10559.0
# 31423   46201     31233.0      1803.0           31651.0        10004.0
# 13917   46224     37197.0      1277.0           40965.0         8962.0
# 5506    46218     28950.0      1638.0           26615.0         8596.0
# 19139   46227     55806.0       867.0           44873.0         8595.0
# 13915   46203     38184.0      1223.0           41321.0         8236.0
# 2736    46235     32729.0      1055.0           41083.0         7333.0
# 20461   46241     32297.0       915.0           42342.0         7187.0
# 13921   46254     40206.0      1326.0           46693.0         6475.0
# 20459   46219     37192.0      1445.0           42749.0         6102.0
# 5492    46260     35582.0       688.0           59522.0         6042.0
# ...

# %%
indianapolis_df = indianapolis_df.dropna()

# %%
desired_zip_codes = ["46107", "46183", "46201", "46202", "46203", "46204", "46205", "46206", "46207", "46208", "46214", "46214", "46216",
      "46217", "46217", "46218", "46219", "46220", "46221", "46222", "46224", "46224", "46225", "46226", "46226", "46227",
      "46227", "46228", "46229", "46229", "46230", "46231", "46231", "46234", "46234", "46235", "46235", "46236", "46236",
      "46237", "46237", "46239", "46239", "46240", "46240", "46241", "46241", "46242", "46244", "46247", "46247", "46250",
      "46250", "46251", "46253", "46253" ,"46254", "46254", "46256", "46256", "46259", "46259", "46260", "46260", "46268",
      "46268", "46278", "46278", "46282"]

# %%
numeric_columns_indy = indianapolis_df.select_dtypes(include='number')
indy_stats_data = numeric_columns_indy.mean()
indy_std_data = numeric_columns_indy.std(skipna=True)  # Set skipna=True to exclude NaN values

indy_stats = pd.DataFrame(indy_stats_data).transpose()
indy_stats.index = ['Indianapolis']

indy_std = pd.DataFrame(indy_std_data).transpose()
indy_std.index = ['Indy Std Dev']

indy_stats = pd.concat([indy_stats, indy_std])

indy_stats
# Out:
#                 Population  Unemployed  Household Income  Poverty Count  \
# Indianapolis  26925.833333  789.750000      57882.972222    4282.166667
# Indy Std Dev  12000.788347  527.769234      22208.635591    3263.275143
#
#               Poverty Rate
# Indianapolis     14.936402
# Indy Std Dev      8.043167

# %%
combined_stats = pd.concat([cleveland_stats, dallas_stats, indy_stats, missoula_stats, sanfransisco_stats, seattle_stats, virginia_stats])
combined_stats
# Out:
#                         Population   Unemployed  Household Income  \
# Cleveland             26323.500000  1201.187500      42551.031250
# Cleveland Std Dev     12060.999472   591.753787      15205.223579
# Dallas                34036.292683   875.743902      70395.439024
# Dallas Std Dev        19905.006869   568.097297      29222.360059
# Indianapolis          26925.833333   789.750000      57882.972222
# Indy Std Dev          12000.788347   527.769234      22208.635591
# Missoula              20119.600000   610.800000      62277.400000
# Missoula Std Dev       9034.971461   475.842096      15824.567571
# Sanfransisco          33290.500000   979.846154     122571.807692
# Sanfransisco Std Dev  20869.592911   647.706952      50897.949615
# Seattle               30698.090909   814.030303      93888.757576
# Seattle Std Dev       11795.062975   357.515427      22924.554596
# Virginia Minnesota     9689.000000   268.000000      44213.000000
#
# ...

# %%
c = Census(
    census_api_key,
    year = 2018
)

# %%
census_data_2018 = c.acs5.get(
    (
        "NAME",
        "B19013_001E",
        "B01003_001E",
        "B17001_002E",
        "B23025_005E"
    ),
    {'for': 'zip code tabulation area:*'}
)

# Convert to DataFrame
census_df_2018 = pd.DataFrame(census_data_2018)

# Column renaming
census_df_2018 = census_df_2018.rename(
    columns = {
        "B01003_001E": "Population",
        "B19013_001E": "Household Income",
        "B17001_002E": "Poverty Count",
        "B23025_005E": "Unemployed",
        "NAME": "Name",
        "zip code tabulation area": "Zipcode"
    }
)

# Add a Poverty Rate column (Poverty Count / Population)
census_df_2018["Poverty Rate"] = 100 * census_df_2018["Poverty Count"].astype(int) / census_df_2018["Population"].astype(int)

# Configure the final DataFrame
census_df_2018 = census_df_2018[
    [
        "Zipcode",
        "Population",
        'Unemployed',
        "Household Income",
        "Poverty Count",
        "Poverty Rate"
        
    ]
]

# Display DataFrame length and sample data
print(f"Number of rows in the DataFrame: {len(census_df_2018)}")
census_df_2018.head()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[54], line 28
#      16 census_df_2018 = census_df_2018.rename(
#      17     columns = {
#      18         "B01003_001E": "Population",
#    (...)
#      24     }
#      25 )
#      27 # Add a Poverty Rate column (Poverty Count / Population)
# ---> 28 census_df_2018["Poverty Rate"] = 100 * census_df_2018["Poverty Count"].astype(int) / census_df_2018["Population"].astype(int)
#      30 # Configure the final DataFrame
#      31 census_df_2018 = census_df_2018[
#      32     [
#      33         "Zipcode",
#    (...)
#      40     ]
#      41 ]
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
# ...

# %%
poverty_df_2018 = census_df_2018.sort_values(by='Poverty Count', ascending=False)
poverty_df_2018.head()

# %%
desired_zip_codes = ['98101', '98102', '98103', '98104', '98105', '98106', '98107', '98108', '98109', '98110', '98111', '98112', '98113', '98114', '98115', '98116', '98117', '98118', '98119', '98121', '98122', '98124', '98125', '98126', '98127', '98129', '98131', '98133','98136', '98138', '98139', '98141', '98144', '98145', '98146', '98148', '98155', '98160', '98161', '98165', '98166', '98168', '98170', '98175', '98177', '98178', '98181', '98185', '98188', '98190', '98191', '98194', '98198', '98199']

seattle_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

seattle_df_2018

# %%
seattle_df_2018 = seattle_df_2018.dropna()

# %%
numeric_columns_seattle_2018 = seattle_df_2018.select_dtypes(include='number')
seattle_stats_data_2018 = numeric_columns_seattle_2018.mean()
seattle_std_data_2018 = numeric_columns_seattle_2018.std(skipna=True)

seattle_stats_2018 = pd.DataFrame(seattle_stats_data_2018).transpose()
seattle_stats_2018.index = ['Seattle 2018']

seattle_std_2018 = pd.DataFrame(seattle_std_data_2018).transpose()
seattle_std_2018.index = ['Seattle Std Dev 2018']

seattle_stats_2018 = pd.concat([seattle_stats_2018, seattle_std_2018])

seattle_stats_2018

# %%
desired_zip_codes = ["75001", "75006", "75007", "75019", "75032", "75039", "75041", "75042", "75043", "75050", "75051", "75052", "75061",
          "75062", "75063", "75080", "75081", "75087", "75088", "75089", "75093", "75098", "75104", "75115", "75116", "75126",
          "75134", "75149", "75150", "75159", "75166", "75180", "75181", "75182", "75201", "75202", "75203", "75204", "75205",
          "75206", "75207", "75208", "75209", "75210", "75211", "75212", "75214", "75215", "75216", "75217", "75218", "75219",
          "75220", "75221", "75222", "75223", "75224", "75225", "75226", "75227", "75228", "75229", "75230", "75231", "75232",
          "75233", "75234", "75235", "75236", "75237", "75238", "75240", "75241", "75242", "75243", "75244", "75246", "75247",
          "75248", "75249", "75250", "75251", "75252", "75253", "75254", "75260", "75261", "75262", "75263", "75264", "75265",
          "75266", "75267", "75270", "75275", "75277", "75283", "75284", "75285", "75287", "75301", "75303", "75312", "75313",
          "75315", "75320", "75326", "75336", "75339", "75342", "75354", "75355", "75356", "75357", "75358", "75359", "75360",
          "75367", "75368", "75370", "75371", "75372", "75373", "75374", "75376", "75378", "75379", "75380", "75381", "75382",
          "75389", "75390", "75391", "75392", "75393", "75394", "75395", "75397", "75398"]

dallas_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

# %%
dallas_df_2018 = dallas_df_2018.dropna()

# %%
numeric_columns_dallas_2018 = dallas_df_2018.select_dtypes(include='number')
dallas_stats_data_2018 = numeric_columns_dallas_2018.mean()
dallas_std_data_2018 = numeric_columns_dallas_2018.std(skipna=True)

dallas_stats_2018 = pd.DataFrame(dallas_stats_data_2018).transpose()
dallas_stats_2018.index = ['Dallas 2018']

dallas_std_2018 = pd.DataFrame(dallas_std_data_2018).transpose()
dallas_std_2018.index = ['Dallas Std Dev 2018']

dallas_stats_2018 = pd.concat([dallas_stats_2018, dallas_std_2018])

dallas_stats_2018

# %%
desired_zip_codes = ["94101", "94102", "94103", "94104", "94105", "94107", "94108", "94109", "94110", "94111", "94112", "94114",
                 "94115", "94116", "94117", "94118", "94119", "94120", "94121", "94122", "94123", "94124", "94125", "94126",
                 "94127", "94129", "94130", "94131", "94132", "94133", "94134", "94140", "94141", "94142", "94146", "94147",
                 "94157", "94159", "94164", "94165", "94166", "94167", "94168", "94169", "94170", "94172", "94188"]

sanfransisco_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

sanfransisco_df_2018 = sanfransisco_df_2018.dropna()

# %%
numeric_columns_sanfransisco_2018 = sanfransisco_df_2018.select_dtypes(include='number')
sanfransisco_stats_data_2018 = numeric_columns_sanfransisco_2018.mean()
sanfransisco_std_data_2018 = numeric_columns_sanfransisco_2018.std(skipna=True)

sanfransisco_stats_2018 = pd.DataFrame(sanfransisco_stats_data_2018).transpose()
sanfransisco_stats_2018.index = ['Sanfransisco 2018']

sanfransisco_std_2018 = pd.DataFrame(sanfransisco_std_data_2018).transpose()
sanfransisco_std_2018.index = ['Sanfransisco Std Dev 2018']

sanfransisco_stats_2018 = pd.concat([sanfransisco_stats_2018, sanfransisco_std_2018])

sanfransisco_stats_2018

# %%
desired_zip_codes = ["44102", "44103", "44104", "44105", "44106", "44107", "44108", "44109", "44110", "44111", "44112", "44113",
             "44114", "44115", "44117", "44118", "44119", "44120", "44121", "44124", "44125", "44126", "44127", "44128", "44129",
             "44130", "44134", "44135", "44137", "44142", "44143", "44144", "44181", "44188", "44190", "44191", "44192" ,"44193",
             "44194", "44195", "44197", "44198", "44199"]

cleveland_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

# %%
cleveland_df_2018 = cleveland_df_2018.dropna()

# %%
numeric_columns_cleveland_2018 = cleveland_df_2018.select_dtypes(include='number')
cleveland_stats_data_2018 = numeric_columns_cleveland_2018.mean()
cleveland_std_data_2018 = numeric_columns_cleveland_2018.std(skipna=True)

cleveland_stats_2018 = pd.DataFrame(cleveland_stats_data_2018).transpose()
cleveland_stats_2018.index = ['Cleveland 2018']

cleveland_std_2018 = pd.DataFrame(cleveland_std_data_2018).transpose()
cleveland_std_2018.index = ['Cleveland Std Dev 2018']

cleveland_stats_2018 = pd.concat([cleveland_stats_2018, cleveland_std_2018])

cleveland_stats_2018

# %%
desired_zip_codes = ["59801", "59802", "59803", "59804", "59806", "59807", "59808"]

missoula_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

# %%
missoula_df_2018 = missoula_df_2018.dropna()

# %%
numeric_columns_missoula_2018 = missoula_df_2018.select_dtypes(include='number')
missoula_stats_data_2018 = numeric_columns_missoula_2018.mean()
missoula_std_data_2018 = numeric_columns_missoula_2018.std(skipna=True)

missoula_stats_2018 = pd.DataFrame(missoula_stats_data_2018).transpose()
missoula_stats_2018.index = ['Missoula 2018']

missoula_std_2018 = pd.DataFrame(missoula_std_data_2018).transpose()
missoula_std_2018.index = ['Missoula Std Dev 2018']

missoula_stats_2018 = pd.concat([missoula_stats_2018, missoula_std_2018])

missoula_stats_2018

# %%
desired_zip_codes = ['55792']

virginia_minnesota_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]

virginia_minnesota_df_2018

# %%
numeric_columns_2018 = virginia_minnesota_df_2018.select_dtypes(include='number')
virginia_stats_data_2018 = numeric_columns_2018.mean()
virginia_std_data_2018 = numeric_columns_2018.std(skipna=True)

virginia_stats_2018 = pd.DataFrame(virginia_stats_data_2018).transpose()
virginia_stats_2018.index = ['Virginia Minnesota 2018']

virginia_stats_2018 = pd.concat([virginia_stats_2018])

virginia_stats_2018

# %%
desired_zip_codes = ["46107", "46183", "46201", "46202", "46203", "46204", "46205", "46206", "46207", "46208", "46214", "46214", "46216",
      "46217", "46217", "46218", "46219", "46220", "46221", "46222", "46224", "46224", "46225", "46226", "46226", "46227",
      "46227", "46228", "46229", "46229", "46230", "46231", "46231", "46234", "46234", "46235", "46235", "46236", "46236",
      "46237", "46237", "46239", "46239", "46240", "46240", "46241", "46241", "46242", "46244", "46247", "46247", "46250",
      "46250", "46251", "46253", "46253" ,"46254", "46254", "46256", "46256", "46259", "46259", "46260", "46260", "46268",
      "46268", "46278", "46278", "46282"]

indianapolis_df_2018 = poverty_df_2018[poverty_df_2018['Zipcode'].isin(desired_zip_codes)]
indianapolis_df_2018

# %%
indianapolis_df_2018 = indianapolis_df_2018.dropna()

# %%
numeric_columns_indy_2018 = indianapolis_df_2018.select_dtypes(include='number')
indy_stats_data_2018 = numeric_columns_indy_2018.mean()
indy_std_data_2018 = numeric_columns_indy_2018.std(skipna=True)

indy_stats_2018 = pd.DataFrame(indy_stats_data_2018).transpose()
indy_stats_2018.index = ['Indianapolis 2018']

indy_std_2018 = pd.DataFrame(indy_std_data_2018).transpose()
indy_std_2018.index = ['Indy Std Dev 2018']

indy_stats_2018 = pd.concat([indy_stats_2018, indy_std_2018])

indy_stats_2018

# %%
combined_stats_2018 = pd.concat([cleveland_stats_2018, dallas_stats_2018, indy_stats_2018, missoula_stats_2018, sanfransisco_stats_2018, seattle_stats_2018, virginia_stats_2018])
combined_stats_2018

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia Minnesota']
poverty_rates_2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]

# Create bar plot
plt.bar(cities, poverty_rates, color='blue')
plt.xlabel('City')
plt.ylabel('Poverty Rate')
plt.title('2021 Poverty Rates for Cities')
plt.ylim(0, 30)  # Set the y-axis range if needed
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization

# Show plot
plt.show()

# %%
# Data
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia Minnesota']
poverty_rates_2017 = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]
poverty_rates_2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]

# Set the bar width
bar_width = 0.35
index = np.arange(len(cities))

# Create grouped bar plot
plt.bar(index, poverty_rates_2017, bar_width, color='turquoise', edgecolor = 'blue', label='2017')
plt.bar(index + bar_width, poverty_rates_2020, bar_width, color='teal', edgecolor = 'gray', label='2020')

plt.xlabel('City')
plt.ylabel('Poverty Rate')
plt.title('Poverty Rates for Cities in 2017 and 2020')
plt.xticks(index + bar_width / 2, cities, rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
cities = ['Cleveland','Cleveland(2020)', 'Dallas', 'Dallas(2020)', 'Indianapolis', 'Indianapolis(2020)', 'Missoula', 'Missoula(2020)', 'Sanfransisco', 'Sanfransisco(2020)', 'Seattle', 'Seattle(2020)', 'Virginia Minnesota', 'Virginia Minnesota(2020)']
poverty_rates_2017 = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]
poverty_rates_2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]

plt.bar(cities[0], poverty_rates_2017[0], label=poverty_rates_2017[0], color='pink')
plt.bar(cities[1], poverty_rates_2020[0], label=poverty_rates_2020[0], color='pink', edgecolor='black',)
plt.bar(cities[2], poverty_rates_2017[1], label=poverty_rates_2017[1], color='yellow')
plt.bar(cities[3], poverty_rates_2020[1], label=poverty_rates_2020[1], color='yellow', edgecolor='black')
plt.bar(cities[4], poverty_rates_2017[2], label=poverty_rates_2017[2], color='blue')
plt.bar(cities[5], poverty_rates_2020[2], label=poverty_rates_2020[2], color='blue', edgecolor='black')
plt.bar(cities[6], poverty_rates_2017[3], label=poverty_rates_2017[3], color='purple')
plt.bar(cities[7], poverty_rates_2020[3], label=poverty_rates_2020[3], color='purple', edgecolor='black')
plt.bar(cities[8], poverty_rates_2017[4], label=poverty_rates_2017[4], color='orange')
plt.bar(cities[9], poverty_rates_2020[4], label=poverty_rates_2020[4], color='orange', edgecolor='black')
plt.bar(cities[10], poverty_rates_2017[5], label=poverty_rates_2017[5], color='green')
plt.bar(cities[11], poverty_rates_2020[5], label=poverty_rates_2020[5], color='green', edgecolor='black')
plt.bar(cities[12], poverty_rates_2017[6], label=poverty_rates_2017[6], color='red')
plt.bar(cities[13], poverty_rates_2020[6], label=poverty_rates_2020[6], color='red', edgecolor='black')

plt.xlabel('City')
plt.ylabel('Poverty Rate')
plt.title('Poverty Rates for Cities in 2017 and 2020')
plt.xticks(cities, rotation=90)

# Show plot
plt.tight_layout()
plt.show()

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia(MN)']
poverty_rates_2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]

# Create line plot
plt.plot(cities, poverty_rates_2020, marker='o', linestyle='-', color='green')
plt.title('Poverty in Different Cities')
plt.xlabel('City')
plt.ylabel('Poverty Rates')
plt.grid(True)
# Show plot
plt.show()

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia(MN)']
poverty_rates_city2017 = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]
poverty_rates_city2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]

# Create line plot for the first city
plt.plot(cities, poverty_rates_city2017, marker='s', linestyle='-', color='turquoise', markerfacecolor='blue', markersize=7, label='2017 Poverty')

# Create line plot for the second city
plt.plot(cities, poverty_rates_city2020, marker='o', linestyle='-', color='teal', markerfacecolor='gray', markersize=7, label='2020 Poverty')

plt.title('Poverty Rates in Different Cities')
plt.xlabel('City')
plt.ylabel('Poverty Rates')
plt.legend()

# Show plot
plt.show()

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia(MN)']
poverty_rates_city2017 = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]
poverty_rates_city2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]
unemployed2017 = [1473.50, 988.30, 1087.06, 684.80, 1111.08, 858.21, 261]
unemployed2020 = [1201.19, 875.74, 789.75, 610.8, 979.85, 814.03, 268]
# Create line plot for the first city
plt.plot(cities, poverty_rates_city2017, marker='s', linestyle='-', color='turquoise', markerfacecolor='blue', markersize=7, label='2017 Poverty')

# Create line plot for the second city
plt.plot(cities, poverty_rates_city2020, marker='o', linestyle='-', color='teal', markerfacecolor='gray', markersize=7, label='2020 Poverty')

plt.title('Poverty Rates in Different Cities')
plt.xlabel('City')
plt.ylabel('Poverty Rates')
plt.legend()

# Show plot
plt.show()

# %%
cities = ['Cleveland', 'Dallas', 'Indianapolis', 'Missoula', 'Sanfransisco', 'Seattle', 'Virginia(MN)']
poverty_rates_city2017 = [26.24, 17.12, 17.59, 14.77, 13.60, 11.92, 20.97]
poverty_rates_city2020 = [24.02, 14.23, 14.94, 11.77, 11.72, 9.69, 21.92]
unemployed2017 = [1473.50, 988.30, 1087.06, 684.80, 1111.08, 858.21, 261]
unemployed2020 = [1201.19, 875.74, 789.75, 610.8, 979.85, 814.03, 268]
# Create line plot for the first city
plt.plot(cities, poverty_rates_city2017, marker='s', linestyle='-', color='turquoise', markerfacecolor='blue', markersize=7, label='2017 Poverty')

# Create line plot for the second city
plt.plot(cities, poverty_rates_city2020, marker='o', linestyle='-', color='teal', markerfacecolor='gray', markersize=7, label='2020 Poverty')

plt.title('Poverty Rates in Different Cities')
plt.xlabel('City')
plt.ylabel('Poverty Rates')
plt.legend()

# Show plot
plt.show()
